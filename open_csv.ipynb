# %%
import matplotlib.pyplot as plt
import pandas as pd

from scipy.ndimage import gaussian_filter
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0004.csv')
wvn = df['wvn']
raw = df['raw']
bckg = df['bckg']
signal = df['signal']

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0000.csv')
wvn = df['wvn']
raw = df['raw']
bckg = df['bckg']
signal = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0001.csv')
wvn = df['wvn']
raw = df['raw']
bckg = df['bckg']
signal = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0002.csv')
wvn = df['wvn']
raw = df['raw']
bckg = df['bckg']
signal = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0003.csv')
wvn = df['wvn']
raw = df['raw']
bckg = df['bckg']
signal = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0004.csv')
wvn = df['wvn']
raw = df['raw']
bckg = df['bckg']
signal = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
with open('/tmp/peaks', 'r') as f:
    peaks = [ int(x) for x in f.read().split(',') ]

# %%
print(peaks[:3])
# Out:
# [17, 31, 122]

# %%
plt.figure(figsize=(15, 6))
plt.plot(raw, 'g', lw=1)
for x in peaks:
    plt.axvline(x)

# %%
plt.figure(figsize=(15,6))
plt.plot(raw)

# %%
import numpy as np

from scipy.fft import fft, ifft

# %%
plt.figure(figsize=(15,6))
f = fft(np.array(raw))
plt.plot(f)
# Out:
# /home/noa/projects/raman-processing/venv/lib/python3.11/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/noa/projects/raman-processing/venv/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.figure(figsize=(15,6))
x = 30
# plt.plot(ifft(f[:x]))
# plt.plot(np.linspace(0, x, len(raw)-x), ifft(f[x:])*60)
plt.plot(np.linspace(0, x, len(raw)), raw*30)
