# %%
import matplotlib.pyplot as plt
import pandas as pd

from scipy.ndimage import gaussian_filter
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# %%
df
# Out:
#         px          wvn   raw  signal
# 0     1791   341.352485  1689     -43
# 1     1790   343.857120  1694     -39
# 2     1789   346.361756  1703     -30
# 3     1788   348.866391  1714     -20
# 4     1787   351.371026  1721     -14
# ...    ...          ...   ...     ...
# 1787     4  4817.135818   603       5
# 1788     3  4819.640454   595      -3
# 1789     2  4822.145089   595      -3
# 1790     1  4824.649724   590      -8
# 1791     0  4827.154360   589      -9
#
# [1792 rows x 4 columns]

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0000.csv')
wvn = df['wvn']
raw = df['raw']
signal = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0000.csv')
wvn = df['wvn']
signal0 = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal0, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0001.csv')
signal1 = df['signal'][:-3]

plt.figure(figsize=(15,6))
plt.plot(wvn, signal1, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0002.csv')
signal2 = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal2, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0003.csv')
signal3 = df['signal']

plt.figure(figsize=(15,6))
plt.plot(wvn, signal3, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
df = pd.read_csv('data/20240306/E1_2024-03-06-170901-0004.csv')
signal4 = df['signal'][:-2]

plt.figure(figsize=(15,6))
plt.plot(wvn, signal4, lw=1)
plt.axhline(0, c='gray', ls='--')

# %%
plt.figure(figsize=(15,30))
plt.plot(wvn, signal0, lw=1, c='xkcd:red')
plt.plot(wvn, signal1+200, lw=1, c='xkcd:orange')
plt.plot(wvn, signal2+400, lw=1, c='xkcd:yellow')
plt.plot(wvn, signal3+600, lw=1, c='xkcd:green')
plt.plot(wvn, signal4+800, lw=1, c='xkcd:blue')
plt.axhline(0, c='gray', ls='--')
